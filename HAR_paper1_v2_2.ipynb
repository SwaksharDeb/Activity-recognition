# %% [markdown]
# # Importing dependecies

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import csv
import array
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from numpy import savetxt
from sklearn.preprocessing import StandardScaler
from collections import Counter
from sklearn.model_selection import train_test_split
import tensorflow as tf
import scipy.stats as stats
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam
from math import sqrt
import math

# %%
from scipy.fftpack import fft
from scipy.stats import spearmanr
from scipy.stats import pearsonr

# %% [markdown]
# # Import dataset

# %%
"""Import Datasets"""
dataset_user04 = pd.read_csv("final_field_user04_dataset.csv")
dataset_user07 = pd.read_csv("final_field_user07_dataset.csv")
dataset_user08 = pd.read_csv("final_field_user08_dataset.csv")
dataset_user18 = pd.read_csv("final_field_user18_dataset.csv")
dataset_user38 = pd.read_csv("final_field_user38_dataset.csv")
dataset_user51 = pd.read_csv("final_field_user51_dataset.csv")
dataset_lab = pd.read_csv("lab data localized.csv")

dataset = pd.concat([dataset_lab, dataset_user04, dataset_user07, dataset_user08, dataset_user18, dataset_user38, dataset_user51], ignore_index = True)

# %% [markdown]
# # Data processing

# %%
""" Data processing"""
X = dataset.iloc[:, [0, 1, 2]].values
Y = dataset.iloc[:, 3].values
Y = Y - 1

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# we just use scaling for data augmentation. The minority classes are scaled and added to the original data to make the original data balance. Our assumption is that, if we scale a signal it still represent the same activity

# %%
# Data Augmentation
scalling_factor = [0.3,0.5,0.7,0.8,1.2,1.5,2]

for scal in scalling_factor:
    X_1_scal = X[np.where(Y==1)]*scal
    label_1 = Y[np.where(Y==1)]
    X_2_scal = X[np.where(Y==2)]*scal
    label_2 = Y[np.where(Y==2)]
    X_5_scal = X[np.where(Y==5)]*scal
    label_5 = Y[np.where(Y==5)]
    X_7_scal = X[np.where(Y==7)]*scal
    label_7 = Y[np.where(Y==7)]
    X_8_scal = X[np.where(Y==8)]*scal
    label_8 = Y[np.where(Y==8)]
    X_9_scal = X[np.where(Y==9)]*scal
    label_9 = Y[np.where(Y==9)]
    X_10_scal = X[np.where(Y==10)]*scal
    label_10 = Y[np.where(Y==10)]
    X = np.concatenate((X, X_1_scal,X_2_scal,X_5_scal,X_7_scal,X_8_scal,X_9_scal,X_10_scal))
    Y = np.concatenate((Y, label_1,label_2, label_5, label_7, label_8, label_9, label_10))

scalling_factor = [0.5,2]

for scal in scalling_factor:
    X_3_scal = X[np.where(Y==3)]*scal
    label_3 = Y[np.where(Y==3)]
    X_11_scal = X[np.where(Y==11)]*scal
    label_11 = Y[np.where(Y==11)]
    X = np.concatenate((X, X_3_scal, X_11_scal))
    Y = np.concatenate((Y, label_3, label_11))

scalling_factor = [0.3,0.5,1.5,2]

for scal in scalling_factor:
    X_0_scal = X[np.where(Y==0)]*scal
    label_0 = Y[np.where(Y==0)]
    X_6_scal = X[np.where(Y==6)]*scal
    label_6 = Y[np.where(Y==6)]
    X = np.concatenate((X, X_0_scal, X_6_scal))
    Y = np.concatenate((Y, label_0, label_6))

# %%
del X_1_scal

# %%
X.shape,Y.shape
# Out:
# ((26992376, 3), (26992376,))

# %% [markdown]
# ## low pass filter

# %%
low_pass_filter = np.zeros((X.shape[0], X.shape[1]))
for i in range(len(X)):
    for j in range(X.shape[1]):
        if i == 0:
            low_pass_filter[i][j] = X[i][j]
        else:
            low_pass_filter[i][j] = 0.8*X[i-1][j] + (1-0.8)*X[i][j]

# %% [markdown]
# ## Frame preparation

# %%
# frame preparation
Fs = 4
frame_size = Fs*20 # 80 # 20 seconds of data
hop_size =  Fs*10

def get_frames(df, frame_size, hop_size,label_data):

    N_FEATURES = 3

    frames = []
    labels = []
    for i in range(0, len(df) - frame_size, hop_size):
        value = df[i: i + frame_size, :]
        #y = df[i: i + frame_size, 1]
        #z = df[i: i + frame_size, 2]

        # Retrieve the most often used label in this segment
        label = stats.mode(label_data[i: i + frame_size])[0][0]
        frames.append([value])
        labels.append(label)

    # Bring the segments into a better shape
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)

    return frames, labels

row_frame, row_label = get_frames(X, frame_size, hop_size, Y)
low_pass_frame, low_pass_label = get_frames(low_pass_filter, frame_size, hop_size, Y)

# %%
row_frame.shape, low_pass_frame.shape
# Out:
# ((674808, 80, 3), (674808, 80, 3))

# %% [markdown]
# ## Feature calculation

# %%
#feature calculation
mean = np.mean(low_pass_frame, axis = 1)  # mean along (x,y,z) axis
std = np.std(low_pass_frame, axis = 1)  # standard deviation along (x,y,z) axis

rms_x = []  # root mean square along x axis
value = 0
for i in range(low_pass_frame.shape[0]):
    for j in range(low_pass_frame.shape[1]):
        value = value + (low_pass_frame[i][j][0] **2)
        value = value / (low_pass_frame.shape[1])
    value = sqrt(value)
    rms_x.append(value)
    value = 0

rms_y = []  # root mean square along y axis
for i in range(low_pass_frame.shape[0]):
    for j in range(low_pass_frame.shape[1]):
        value = value + (low_pass_frame[i][j][1] **2)
        value = value / (low_pass_frame.shape[1])
    value = sqrt(value)
    rms_y.append(value)
    value = 0

rms_z = []  # root mean square z axis
for i in range(low_pass_frame.shape[0]):
    for j in range(low_pass_frame.shape[1]):
        value = value + (low_pass_frame[i][j][2] **2)
        value = value / (low_pass_frame.shape[1])
    value = sqrt(value)
    rms_z.append(value)
    value = 0

# %%
lengths = []  # length of the accelerometer vector
length = 0
nx, ny, nz = row_frame.shape[0], row_frame.shape[1], row_frame.shape[2]
acc_vector = np.reshape(row_frame,(nx, ny*nz))

for i in range(acc_vector.shape[0]):
    count = 0
    for j in range(acc_vector.shape[1]):
        length += acc_vector[i][j]**2
        count += 1

        if count == 3:
            length = sqrt(length)
            lengths.append(length)
            length = 0
            count = 0

avc = []  # avc feature

polling_rate = 4 #Hz

for i in range(0, len(lengths), frame_size):
    value = 0
    iterable = lengths[i:i+frame_size]
    for j in range(len(iterable) - 1, 1, -1):
        value += abs(iterable[j] - iterable[j - 1])

    value = value / (frame_size / polling_rate)
    avc.append(value)

# %%
max_min = []

for i in range(0, len(lengths), frame_size):
    iterable = lengths[i:i+frame_size]

    max_min.append(max(iterable) - min(iterable))

# %%
angle = np.zeros((low_pass_frame.shape[0],low_pass_frame.shape[1],low_pass_frame.shape[2]))  # inclenation angle
angles = []
length = 0
for i in range(angle.shape[0]):
    for j in range(angle.shape[1]):
        length = low_pass_frame[i,j,0]**2 + low_pass_frame[i,j,1]**2 + low_pass_frame[i,j,2]**2
        length = sqrt(length)
        if length == 0:
            print("length is zero in index row= ",i,"column= ",j)
        else:
            angle_x = math.acos(low_pass_frame[i,j,0]/length)
            angle_y = math.acos(low_pass_frame[i,j,1]/length)
            angle_z = math.acos(low_pass_frame[i,j,2]/length)
            angle[i][j][0] = angle_x
            angle[i][j][1] = angle_y
            angle[i][j][2] = angle_z
nx, ny, nz = angle.shape
angle = np.reshape(angle,(nx,ny*nz))

# %%
fft_x = []  # fast fourier transform cofficient along x axis
for i in range(row_frame.shape[0]):
  fft_x.append(fft(row_frame[i,:,0]))

fft_y = []  # fast fourier transform cofficient along x axis
for i in range(row_frame.shape[0]):
  fft_y.append(fft(row_frame[i,:,1]))

fft_z = []  # fast fourier transform cofficient along x axis
for i in range(row_frame.shape[0]):
  fft_z.append(fft(row_frame[i,:,2]))

energy_x = []
modulus_square = 0
for i in fft_x:
  for j in range(len(fft_x[0])):
    modulus_square += i[j].real**2 + i[j].imag**2
  energy_x.append(modulus_square/len(fft_x[0]))
  modulus_square = 0

energy_y = []
for i in fft_y:
  for j in range(len(fft_y[0])):
    modulus_square += i[j].real**2 + i[j].imag**2
  energy_y.append(modulus_square/len(fft_x[0]))
  modulus_square = 0

energy_z = []
for i in fft_z:
  for j in range(len(fft_z[0])):
    modulus_square += i[j].real**2 + i[j].imag**2
  energy_z.append(modulus_square/len(fft_x[0]))
  modulus_square = 0
'''
correlation = np.zeros((row_frame.shape[0],3))
for i in range(row_frame.shape[0]):
  corr_xy, _ =  pearsonr(row_frame[i,:,0], row_frame[i,:,1])
  corr_yz, _ =  pearsonr(row_frame[i,:,1], row_frame[i,:,2])
  corr_xz, _ =  pearsonr(row_frame[i,:,0], row_frame[i,:,2])
  correlation[i][0] = corr_xy
  correlation[i][1] = corr_yz
  correlation[i][2] = corr_xz
'''
# Out:
# '\ncorrelation = np.zeros((row_frame.shape[0],3))\nfor i in range(row_frame.shape[0]):\n  corr_xy, _ =  pearsonr(row_frame[i,:,0], row_frame[i,:,1])\n  corr_yz, _ =  pearsonr(row_frame[i,:,1], row_frame[i,:,2])\n  corr_xz, _ =  pearsonr(row_frame[i,:,0], row_frame[i,:,2])\n  correlation[i][0] = corr_xy\n  correlation[i][1] = corr_yz\n  correlation[i][2] = corr_xz\n'

# %%
# %whos
# Out:
# Variable             Type                          Data/Info
# ------------------------------------------------------------
# Adam                 ABCMeta                       <class 'tensorflow.python<...>.optimizer_v2.adam.Adam'>
# BatchNormalization   type                          <class 'tensorflow.python<...>n_v2.BatchNormalization'>
# Conv2D               type                          <class 'tensorflow.python<...>rs.convolutional.Conv2D'>
# Counter              type                          <class 'collections.Counter'>
# Dense                type                          <class 'tensorflow.python<...>keras.layers.core.Dense'>
# Dropout              type                          <class 'tensorflow.python<...>ras.layers.core.Dropout'>
# Flatten              type                          <class 'tensorflow.python<...>ras.layers.core.Flatten'>
# Fs                   int                           4
# MaxPool2D            type                          <class 'tensorflow.python<...>rs.pooling.MaxPooling2D'>
# MinMaxScaler         type                          <class 'sklearn.preproces<...>sing._data.MinMaxScaler'>
# Sequential           type                          <class 'tensorflow.python<...>e.sequential.Sequential'>
# StandardScaler       type                          <class 'sklearn.preproces<...>ng._data.StandardScaler'>
# X                    ndarray                       26992376x3: 80977128 elems, type `float64`, 647817024 bytes (617.8064575195312 Mb)
# X_0_scal             ndarray                       220176x3: 660528 elems, type `float64`, 5284224 bytes (5.0394287109375 Mb)
# X_10_scal            ndarray                       503744x3: 1511232 elems, type `float64`, 12089856 bytes (11.52978515625 Mb)
# X_11_scal            ndarray                       109598x3: 328794 elems, type `float64`, 2630352 bytes (2.5084991455078125 Mb)
# X_2_scal             ndarray                       6743680x3: 20231040 elems, type `float64`, 161848320 bytes (154.3505859375 Mb)
# X_3_scal             ndarray                       835584x3: 2506752 elems, type `float64`, 20054016 bytes (19.125 Mb)
# X_5_scal             ndarray                       1426368x3: 4279104 elems, type `float64`, 34232832 bytes (32.64697265625 Mb)
# X_6_scal             ndarray                       929592x3: 2788776 elems, type `float64`, 22310208 bytes (21.27667236328125 Mb)
# X_7_scal             ndarray                       398272x3: 1194816 elems, type `float64`, 9558528 bytes (9.11572265625 Mb)
# X_8_scal             ndarray                       586304x3: 1758912 elems, type `float64`, 14071296 bytes (13.41943359375 Mb)
# X_9_scal             ndarray                       555712x3: 1667136 elems, type `float64`, 13337088 bytes (12.71923828125 Mb)
# Y                    ndarray                       26992376: 26992376 elems, type `float64`, 215939008 bytes (205.93548583984375 Mb)
# acc_vector           ndarray                       674808x240: 161953920 elems, type `float64`, 1295631360 bytes (1235.6103515625 Mb)
# angle                ndarray                       674808x240: 161953920 elems, type `float64`, 1295631360 bytes (1235.6103515625 Mb)
# angle_x              float                         1.368176132249945
# angle_y              float                         0.2049417489553329
# angle_z              float                         1.6011357580267647
# angles               list                          n=0
# array                module                        <module 'array' (built-in)>
# avc                  list                          n=674808
# count                int                           0
# csv                  module                        <module 'csv' from '/usr/lib/python3.6/csv.py'>
# dataset              DataFrame                                  x       y   <...>1867777 rows x 4 columns]
# dataset_lab          DataFrame                               x     y     z  <...>n[88009 rows x 4 columns]
# dataset_user04       DataFrame                                 x      y     <...>[584350 rows x 4 columns]
# dataset_user07       DataFrame                                 x      y     <...>[185174 rows x 4 columns]
# dataset_user08       DataFrame                                x      y      <...>n[27212 rows x 4 columns]
# dataset_user18       DataFrame                                 x      y     <...>[956701 rows x 4 columns]
# dataset_user38       DataFrame                              x      y      z <...>n\n[844 rows x 4 columns]
# dataset_user51       DataFrame                                x       y     <...>n[25487 rows x 4 columns]
# energy_x             list                          n=674808
# energy_y             list                          n=674808
# energy_z             list                          n=674808
# fft                  function                      <function fft at 0x7f7212768620>
# fft_x                list                          n=674808
# fft_y                list                          n=674808
# fft_z                list                          n=674808
# frame_size           int                           80
# get_frames           function                      <function get_frames at 0x7f7265e72840>
# hop_size             int                           40
# i                    ndarray                       80: 80 elems, type `complex128`, 1280 bytes
# iterable             list                          n=80
# j                    int                           79
# label_0              ndarray                       220176: 220176 elems, type `float64`, 1761408 bytes (1.6798095703125 Mb)
# label_1              ndarray                       646272: 646272 elems, type `float64`, 5170176 bytes (4.9306640625 Mb)
# label_10             ndarray                       503744: 503744 elems, type `float64`, 4029952 bytes (3.84326171875 Mb)
# label_11             ndarray                       109598: 109598 elems, type `float64`, 876784 bytes (856.234375 kb)
# label_2              ndarray                       6743680: 6743680 elems, type `float64`, 53949440 bytes (51.4501953125 Mb)
# label_3              ndarray                       835584: 835584 elems, type `float64`, 6684672 bytes (6.375 Mb)
# label_5              ndarray                       1426368: 1426368 elems, type `float64`, 11410944 bytes (10.88232421875 Mb)
# label_6              ndarray                       929592: 929592 elems, type `float64`, 7436736 bytes (7.09222412109375 Mb)
# label_7              ndarray                       398272: 398272 elems, type `float64`, 3186176 bytes (3.03857421875 Mb)
# label_8              ndarray                       586304: 586304 elems, type `float64`, 4690432 bytes (4.47314453125 Mb)
# label_9              ndarray                       555712: 555712 elems, type `float64`, 4445696 bytes (4.23974609375 Mb)
# length               float                         3.767952542495725
# lengths              list                          n=53984640
# low_pass_filter      ndarray                       26992376x3: 80977128 elems, type `float64`, 647817024 bytes (617.8064575195312 Mb)
# low_pass_frame       ndarray                       674808x80x3: 161953920 elems, type `float64`, 1295631360 bytes (1235.6103515625 Mb)
# low_pass_label       ndarray                       674808: 674808 elems, type `float64`, 5398464 bytes (5.14837646484375 Mb)
# math                 module                        <module 'math' (built-in)>
# max_min              list                          n=674808
# mean                 ndarray                       674808x3: 2024424 elems, type `float64`, 16195392 bytes (15.44512939453125 Mb)
# modulus_square       int                           0
# np                   module                        <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# nx                   int                           674808
# ny                   int                           80
# nz                   int                           3
# pd                   module                        <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# pearsonr             function                      <function pearsonr at 0x7f725203c7b8>
# plt                  module                        <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# polling_rate         int                           4
# rms_x                list                          n=674808
# rms_y                list                          n=674808
# rms_z                list                          n=674808
# row_frame            ndarray                       674808x80x3: 161953920 elems, type `float64`, 1295631360 bytes (1235.6103515625 Mb)
# row_label            ndarray                       674808: 674808 elems, type `float64`, 5398464 bytes (5.14837646484375 Mb)
# savetxt              function                      <function savetxt at 0x7f7272388a60>
# scal                 int                           2
# scalling_factor      list                          n=4
# spearmanr            function                      <function spearmanr at 0x7f725203c9d8>
# sqrt                 builtin_function_or_method    <built-in function sqrt>
# stats                module                        <module 'scipy.stats' fro<...>scipy/stats/__init__.py'>
# std                  ndarray                       674808x3: 2024424 elems, type `float64`, 16195392 bytes (15.44512939453125 Mb)
# tf                   module                        <module 'tensorflow' from<...>/tensorflow/__init__.py'>
# train_test_split     function                      <function train_test_split at 0x7f72510a28c8>
# value                float                         1.530309078705096

# %%
del X_2_scal
del X_3_scal
del X_5_scal
del X_6_scal
del X_7_scal
del X_8_scal
del X_9_scal
del X_10_scal
del X_11_scal

# %%
"""Import Datasets"""
del dataset_user04 
del dataset_user07 
del dataset_user08 
del dataset_user18 
del dataset_user38 
del dataset_user51 
del dataset_lab 

del dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1bfb80490635> in <module>()
#       1 """Import Datasets"""
# ----> 2 del dataset_user04
#       3 del dataset_user07
#       4 del dataset_user08
#       5 del dataset_user18
#
# NameError: name 'dataset_user04' is not defined

# %%
input_vector = np.zeros((row_frame.shape[0], angle.shape[1] + 14))  # input vector for the algorithm
for i in range(input_vector.shape[0]):
    input_vector[i][0] = mean[i][0]
    input_vector[i][1] = mean[i][1]
    input_vector[i][2] = mean[i][2]
    input_vector[i][3] = std[i][0]
    input_vector[i][4] = std[i][1]
    input_vector[i][5] = std[i][2]
    input_vector[i][6] = rms_x[i]
    input_vector[i][7] = rms_y[i]
    input_vector[i][8] = rms_z[i]
    input_vector[i][9] = max_min[i]
    input_vector[i][10] = avc[i]
    input_vector[i,11] = energy_x[i]
    input_vector[i,12] = energy_y[i]
    input_vector[i,13] = energy_z[i]
    #input_vector[i,9] = correlation[i,0]
    #input_vector[i,10] = correlation[i,1]
    #input_vector[i,11] = correlation[i,2]


for i in range(angle.shape[0]):
    for j in range(angle.shape[1]):
        input_vector[i][j+14] = angle[i][j]

# %%
del X
del X_0_scal
del Y 
del acc_vector
del angle
del energy_x
del energy_y
del energy_z
del avc
del fft_x
del fft_y
del fft_z
del label_0
del label_1
del label_2
del label_3
del label_5
del label_6
del label_7
del label_8
del label_9
del label_10
del label_11
del low_pass_filter
del low_pass_frame
del low_pass_label
del rms_x
del rms_y
del rms_z
del std

# %%
input_vector.shape, row_label.shape
# Out:
# ((674808, 254), (674808,))

# %% [markdown]
# # Standarization

# %%
sc = StandardScaler()
input_vector = sc.fit_transform(input_vector)

# %% [markdown]
# # Trian Test split

# %%
X_train, X_val, y_train, y_val = train_test_split(input_vector, row_label, test_size = 0.2, random_state = 0, stratify = row_label)

# %%
X_train.shape, y_train.shape
# Out:
# ((539846, 254), (539846,))

# %% [markdown]
# # Algorithm

# %% [markdown]
# ## Neural Network

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(X_train.shape[1], )))
#model.add(Dropout(0.2))
model.add(Dense(units=64, activation='relu'))
#model.add(Dropout(0.2))
model.add(Dense(units=128, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(units=324, activation='relu'))
#model.add(Dropout(0.2))
model.add(Dense(units=12, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate = 0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs = 50, batch_size =64, validation_data= (X_val, y_val), verbose=1)
# Out:
# Epoch 1/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 1.2101 - accuracy: 0.6275 - val_loss: 1.0698 - val_accuracy: 0.6566
# Epoch 2/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.9889 - accuracy: 0.6810 - val_loss: 0.9342 - val_accuracy: 0.6981
# Epoch 3/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.8905 - accuracy: 0.7123 - val_loss: 0.8648 - val_accuracy: 0.7217
# Epoch 4/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.8296 - accuracy: 0.7314 - val_loss: 0.8228 - val_accuracy: 0.7341
# Epoch 5/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.7874 - accuracy: 0.7460 - val_loss: 0.7791 - val_accuracy: 0.7487
# Epoch 6/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.7525 - accuracy: 0.7557 - val_loss: 0.7686 - val_accuracy: 0.7531
# Epoch 7/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.7267 - accuracy: 0.7640 - val_loss: 0.7322 - val_accuracy: 0.7639
# Epoch 8/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.7072 - accuracy: 0.7700 - val_loss: 0.7277 - val_accuracy: 0.7647
# Epoch 9/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6903 - accuracy: 0.7754 - val_loss: 0.7121 - val_accuracy: 0.7677
# Epoch 10/50
# 8436/8436 [==============================] - 21s 3ms/step - loss: 0.6784 - accuracy: 0.7798 - val_loss: 0.6943 - val_accuracy: 0.7761
# Epoch 11/50
# 8436/8436 [==============================] - 21s 3ms/step - loss: 0.6665 - accuracy: 0.7838 - val_loss: 0.7133 - val_accuracy: 0.7770
# Epoch 12/50
# 8436/8436 [==============================] - 23s 3ms/step - loss: 0.6589 - accuracy: 0.7863 - val_loss: 0.6626 - val_accuracy: 0.7873
# Epoch 13/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6514 - accuracy: 0.7888 - val_loss: 0.6823 - val_accuracy: 0.7784
# Epoch 14/50
# 8436/8436 [==============================] - 21s 3ms/step - loss: 0.6427 - accuracy: 0.7922 - val_loss: 0.6603 - val_accuracy: 0.7872
# Epoch 15/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6362 - accuracy: 0.7943 - val_loss: 0.6516 - val_accuracy: 0.7895
# Epoch 16/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6317 - accuracy: 0.7955 - val_loss: 0.6542 - val_accuracy: 0.7870
# Epoch 17/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6268 - accuracy: 0.7967 - val_loss: 0.6520 - val_accuracy: 0.7912
# Epoch 18/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6209 - accuracy: 0.7990 - val_loss: 0.6481 - val_accuracy: 0.7891
# Epoch 19/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6173 - accuracy: 0.8000 - val_loss: 0.6416 - val_accuracy: 0.7951
# Epoch 20/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6121 - accuracy: 0.8025 - val_loss: 0.6547 - val_accuracy: 0.7889
# Epoch 21/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6086 - accuracy: 0.8032 - val_loss: 0.6363 - val_accuracy: 0.7932
# Epoch 22/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6064 - accuracy: 0.8041 - val_loss: 0.6281 - val_accuracy: 0.8004
# Epoch 23/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.6032 - accuracy: 0.8050 - val_loss: 0.6124 - val_accuracy: 0.8015
# Epoch 24/50
# 8436/8436 [==============================] - 23s 3ms/step - loss: 0.6011 - accuracy: 0.8063 - val_loss: 0.6161 - val_accuracy: 0.8026
# Epoch 25/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5970 - accuracy: 0.8075 - val_loss: 0.6212 - val_accuracy: 0.8032
# Epoch 26/50
# 8436/8436 [==============================] - 23s 3ms/step - loss: 0.5945 - accuracy: 0.8081 - val_loss: 0.6445 - val_accuracy: 0.7937
# Epoch 27/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5925 - accuracy: 0.8085 - val_loss: 0.6258 - val_accuracy: 0.7969
# Epoch 28/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5889 - accuracy: 0.8097 - val_loss: 0.6249 - val_accuracy: 0.7973
# Epoch 29/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5874 - accuracy: 0.8110 - val_loss: 0.6376 - val_accuracy: 0.7964
# Epoch 30/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5848 - accuracy: 0.8118 - val_loss: 0.6137 - val_accuracy: 0.8072
# Epoch 31/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5833 - accuracy: 0.8114 - val_loss: 0.6137 - val_accuracy: 0.8033
# Epoch 32/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5811 - accuracy: 0.8125 - val_loss: 0.6129 - val_accuracy: 0.8049
# Epoch 33/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5792 - accuracy: 0.8135 - val_loss: 0.6047 - val_accuracy: 0.8073
# Epoch 34/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5770 - accuracy: 0.8139 - val_loss: 0.5972 - val_accuracy: 0.8080
# Epoch 35/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5738 - accuracy: 0.8150 - val_loss: 0.6028 - val_accuracy: 0.8086
# Epoch 36/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5727 - accuracy: 0.8154 - val_loss: 0.6129 - val_accuracy: 0.8070
# Epoch 37/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5725 - accuracy: 0.8153 - val_loss: 0.6008 - val_accuracy: 0.8063
# Epoch 38/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5699 - accuracy: 0.8169 - val_loss: 0.5994 - val_accuracy: 0.8130
# Epoch 39/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5690 - accuracy: 0.8166 - val_loss: 0.5934 - val_accuracy: 0.8105
# Epoch 40/50
# 8436/8436 [==============================] - 22s 3ms/step - loss: 0.5668 - accuracy: 0.8173 - val_loss: 0.5953 - val_accuracy: 0.8113
# Epoch 41/50
#  177/8436 [..............................] - ETA: 19s - loss: 0.5571 - accuracy: 0.8189

# %%
y_pred = model.predict(X_val)

# %%
y_pred_ = np.zeros((y_pred.shape[0]))
for i in range(y_pred.shape[0]):
    y_pred_[i] = np.argmax(y_pred[i,:])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_pred_, y_val)

# %%
pd.DataFrame(cm)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_val, y_pred_)

# %%
per_class_accuracy = {}
for i in range(cm.shape[0]):
    accuracy = cm[i,i]/sum(cm[i,:])
    per_class_accuracy[i] = accuracy

# %%
per_class_accuracy
